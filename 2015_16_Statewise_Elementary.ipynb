# %%
import numpy as nmp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("Documents/2015_16_Statewise_Elementary.csv")
print(df.head())
# Out:
#    AC_YEAR  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0  2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1  2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2  2015-16       3            PUNJAB         22     146     13197      1780
# 3  2015-16       4        CHANDIGARH          1      20        84        20
# 4  2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  USCR35  NOTCH_ASS  TCHINV  \
# 0       12549      20.05           16.01  ...    1014      20491    1946
# 1        6857       8.69           11.14  ...     652      36054    3053
# 2       27704      29.82           10.62  ...    2754      88618   14200
# 3        1055      97.25           11.18  ...     117       1994     218
# 4       10117      21.54           13.14  ...    1147      12608    1024
#
# ...

# %%
df.head(5)
# Out:
#    AC_YEAR  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0  2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1  2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2  2015-16       3            PUNJAB         22     146     13197      1780
# 3  2015-16       4        CHANDIGARH          1      20        84        20
# 4  2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  USCR35  NOTCH_ASS  TCHINV  \
# 0       12549      20.05           16.01  ...    1014      20491    1946
# 1        6857       8.69           11.14  ...     652      36054    3053
# 2       27704      29.82           10.62  ...    2754      88618   14200
# 3        1055      97.25           11.18  ...     117       1994     218
# 4       10117      21.54           13.14  ...    1147      12608    1024
#
# ...

# %%
df.isnull().sum()
# Out:
# AC_YEAR      0
# STATCD       0
# STATNAME     0
# DISTRICTS    0
# BLOCKS       0
#             ..
# TOTCLS3G     0
# TOTCLS4G     0
# TOTCLS5G     0
# TOTCLS6G     0
# TOTCLS7G     0
# Length: 816, dtype: int64

# %%
df.describe()
# Out:
#           STATCD  DISTRICTS      BLOCKS      VILLAGES      CLUSTERS  \
# count  36.000000  36.000000   36.000000     36.000000     36.000000
# mean   18.500000  18.888889  203.250000  16520.500000   2289.833333
# std    10.535654  15.947732  220.756928  21166.739773   2645.161756
# min     1.000000   1.000000    1.000000     10.000000      7.000000
# 25%     9.750000   8.000000   35.750000   1038.500000    121.500000
# 50%    18.500000  13.500000  135.500000   8686.000000   1575.500000
# 75%    27.250000  27.750000  306.250000  23341.000000   3865.000000
# max    36.000000  75.000000  971.000000  98470.000000  10594.000000
#
#           TOTPOPULAT  P_URB_POP  POPULATION_0_6  GROWTHRATE     SEXRATIO  ...  \
# count      36.000000  36.000000       36.000000   36.000000    36.000000  ...
# mean    58626.333333  27.678889       13.480556   19.990556   930.888889  ...
# std    165584.055709  18.354991        5.006451   11.455856    79.126581  ...
# ...

# %%
df.isnull().sum()
# Out:
# AC_YEAR      0
# STATCD       0
# STATNAME     0
# DISTRICTS    0
# BLOCKS       0
#             ..
# TOTCLS3G     0
# TOTCLS4G     0
# TOTCLS5G     0
# TOTCLS6G     0
# TOTCLS7G     0
# Length: 816, dtype: int64

# %%
print(df.head())
# Out:
#    AC_YEAR  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0  2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1  2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2  2015-16       3            PUNJAB         22     146     13197      1780
# 3  2015-16       4        CHANDIGARH          1      20        84        20
# 4  2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  USCR35  NOTCH_ASS  TCHINV  \
# 0       12549      20.05           16.01  ...    1014      20491    1946
# 1        6857       8.69           11.14  ...     652      36054    3053
# 2       27704      29.82           10.62  ...    2754      88618   14200
# 3        1055      97.25           11.18  ...     117       1994     218
# 4       10117      21.54           13.14  ...    1147      12608    1024
#
# ...

# %%
df.head()
# Out:
#    AC_YEAR  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0  2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1  2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2  2015-16       3            PUNJAB         22     146     13197      1780
# 3  2015-16       4        CHANDIGARH          1      20        84        20
# 4  2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  USCR35  NOTCH_ASS  TCHINV  \
# 0       12549      20.05           16.01  ...    1014      20491    1946
# 1        6857       8.69           11.14  ...     652      36054    3053
# 2       27704      29.82           10.62  ...    2754      88618   14200
# 3        1055      97.25           11.18  ...     117       1994     218
# 4       10117      21.54           13.14  ...    1147      12608    1024
#
# ...

# %%
pd.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.info()
#
# AttributeError: module 'pandas' has no attribute 'info'

# %%
df.info(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 816 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    AC_YEAR         object
#  1    STATCD          int64
#  2    STATNAME        object
#  3    DISTRICTS       int64
#  4    BLOCKS          int64
#  5    VILLAGES        int64
#  6    CLUSTERS        int64
#  7    TOTPOPULAT      int64
#  8    P_URB_POP       float64
#  9    POPULATION_0_6  float64
#  10   GROWTHRATE      float64
#  11   SEXRATIO        int64
#  12   P_SC_POP        float64
#  13   P_ST_POP        float64
#  14   OVERALL_LI      float64
#  15   FEMALE_LIT      float64
#  16   MALE_LIT        float64
#  17   AREA_SQKM       int64
#  18   TOT_6_10_15     int64
#  19   TOT_11_13_15    int64
#  20   SCH1            int64
#  21   SCH2            int64
#  22   SCH3            int64
#  23   SCH4            int64
#  24   SCH5            int64
#  25   SCH6            int64
#  26   SCH7            int64
# ...

# %% [markdown]
# populations distrubution

# %%
plt.figure(figsize=(20,20))
ab=sns.countplot(data = df,x ="DISTRICTS",)
ab.bar_label(ab.containers[0])
plt.show()

# %%
gb= df.groupby("STATNAME").agg({"DISTRICTS":'mean',"VILLAGES":'mean',"POPULATION_0_6":'mean'})
print(gb)
# Out:
#                       DISTRICTS  VILLAGES  POPULATION_0_6
# STATNAME
# A & N ISLANDS               3.0     198.0           10.40
# ANDHRA PRADESH             13.0   15075.0           10.21
# ARUNACHAL PRADESH          20.0    2982.0           14.66
# ASSAM                      27.0   21833.0           14.47
# BIHAR                      38.0   40779.0           17.90
# CHANDIGARH                  1.0      84.0           11.18
# CHHATTISGARH               27.0   21834.0           14.03
# DADRA & NAGAR HAVELI        1.0      70.0           14.35
# DAMAN & DIU                 2.0      39.0           10.65
# DELHI                       9.0    1201.0           11.76
# GOA                         2.0     530.0            9.57
# GUJARAT                    33.0   19877.0           12.41
# HARYANA                    21.0    7438.0           13.01
# HIMACHAL PRADESH           12.0   10120.0           11.14
# JAMMU & KASHMIR            22.0    7263.0           16.01
# ...

# %%
plt.figure(figsize=(20,30))
sns.heatmap(gb,annot=True)
plt.show()

# %%
# in that case i am asumed minimmun school are avilainble in villige and most of large scholl in fisrt no is madhy pardesh in 5.5and
# second no is maharashtra in 4.4
# thirt is bihar and rajasthan in 4.1

# %%
sns.boxplot(data=df,x="STATCD")
plt.show()

# %%
sns.boxplot(data=df,x="DISTRICTS")
plt.show()

# %%
sns.boxplot(data=df,x="VILLAGES")
plt.show()

# %%
sns.boxplot(data=df,x="POPULATION_0_6")
plt.show()

# %%
print(df["TOTPOPULAT"].unique())
# Out:
# [ 12549   6857  27704   1055  10117  25353  16753  68621 199581 103805
#     608   1383   1981   2722   1091   3671   2964  31169 991348  32966
#   41947  25540  72598  60384    243    343 112373  84666  61131   1458
#      64  33388  72139   1244    380    352]

# %%
print(df["P_URB_POP"].unique())
# Out:
# [20.05  8.69 29.82 97.25 21.54 24.12 77.03 19.26 17.31  8.36  9.85 16.48
#  21.16 40.42 14.87 15.32 11.03 24.55 18.18 13.15 16.39 21.99 31.35 23.61
#  14.72 36.58 24.58 29.38 46.   41.86 24.76 38.1  52.12 30.58 38.67]
